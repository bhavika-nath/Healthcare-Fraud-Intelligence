# %%
import pandas as pd
import numpy as np
import os

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/processed/clean_provider_data.csv")

print("Clean dataset loaded successfully")
print(df.shape)
# Out:
# Clean dataset loaded successfully
# (1296739, 81)

# %%
for i, col in enumerate(df.columns, start=1):
    print(i, col)
# Out:
# 1 rndrng_npi
# 2 rndrng_prvdr_last_org_name
# 3 rndrng_prvdr_first_name
# 4 rndrng_prvdr_mi
# 5 rndrng_prvdr_crdntls
# 6 rndrng_prvdr_ent_cd
# 7 rndrng_prvdr_st1
# 8 rndrng_prvdr_st2
# 9 rndrng_prvdr_city
# 10 rndrng_prvdr_state_abrvtn
# 11 rndrng_prvdr_state_fips
# 12 rndrng_prvdr_zip5
# 13 rndrng_prvdr_ruca
# 14 rndrng_prvdr_ruca_desc
# 15 rndrng_prvdr_cntry
# 16 rndrng_prvdr_type
# 17 rndrng_prvdr_mdcr_prtcptg_ind
# 18 tot_hcpcs_cds
# 19 tot_benes
# 20 tot_srvcs
# 21 tot_sbmtd_chrg
# 22 tot_mdcr_alowd_amt
# 23 tot_mdcr_pymt_amt
# 24 tot_mdcr_stdzd_amt
# 25 drug_sprsn_ind
# 26 drug_tot_hcpcs_cds
# 27 drug_tot_benes
# 28 drug_tot_srvcs
# 29 drug_sbmtd_chrg
# 30 drug_mdcr_alowd_amt
# 31 drug_mdcr_pymt_amt
# 32 drug_mdcr_stdzd_amt
# 33 med_sprsn_ind
# 34 med_tot_hcpcs_cds
# 35 med_tot_benes
# 36 med_tot_srvcs
# 37 med_sbmtd_chrg
# 38 med_mdcr_alowd_amt
# 39 med_mdcr_pymt_amt
# 40 med_mdcr_stdzd_amt
# 41 bene_avg_age
# 42 bene_age_lt_65_cnt
# 43 bene_age_65_74_cnt
# ...

# %%
state_summary = (
    df.groupby("rndrng_prvdr_state_abrvtn")
      .agg(
          total_providers=("rndrng_npi", "nunique"),
          total_beneficiaries=("tot_benes", "sum"),
          total_services=("tot_srvcs", "sum"),
          total_submitted_charges=("tot_sbmtd_chrg", "sum"),
          total_medicare_payments=("tot_mdcr_pymt_amt", "sum"),
          avg_medicare_payment=("tot_mdcr_pymt_amt", "mean")
      )
      .reset_index()
      .sort_values("total_medicare_payments", ascending=False)
)

state_summary.head(10)
# Out:
#    rndrng_prvdr_state_abrvtn  total_providers  total_beneficiaries  \
# 8                         CA           105363             34155154
# 13                        FL            85872             29221303
# 51                        TX            86803             24434786
# 41                        NY            88642             23050569
# 20                        IL            51368             15282421
# 38                        NJ            39694             13968752
# 45                        PA            63361             17019840
# 7                         AZ            26694              8494698
# 26                        MD            26679              9337389
# 34                        NC            44655             12811611
#
#     total_services  total_submitted_charges  total_medicare_payments  \
# 8      380605643.2             5.996005e+10             1.551556e+10
# 13     374407372.1             4.523734e+10             1.200349e+10
# ...

# %%
specialty_summary = (
    df.groupby("rndrng_prvdr_type")
      .agg(
          total_providers=("rndrng_npi", "nunique"),
          total_beneficiaries=("tot_benes", "sum"),
          total_services=("tot_srvcs", "sum"),
          total_submitted_charges=("tot_sbmtd_chrg", "sum"),
          total_medicare_payments=("tot_mdcr_pymt_amt", "sum"),
          avg_medicare_payment=("tot_mdcr_pymt_amt", "mean")
      )
      .reset_index()
      .sort_values("total_medicare_payments", ascending=False)
)

specialty_summary.head(15)
# Out:
#                           rndrng_prvdr_type  total_providers  \
# 66                       Nurse Practitioner           203212
# 69                            Ophthalmology            17519
# 46                        Internal Medicine            93627
# 19                      Clinical Laboratory             2743
# 38                      Hematology-Oncology             9158
# 6                Ambulatory Surgical Center             5667
# 29                          Family Practice            83639
# 5                Ambulance Service Provider             9324
# 25                     Diagnostic Radiology            32843
# 11                               Cardiology            19764
# 88                      Physician Assistant           112514
# 87   Physical Therapist in Private Practice            77901
# 24                              Dermatology            12616
# 77                       Orthopedic Surgery            21674
# ...

# %%
top_payment_providers = (
    df[
        [
            "rndrng_npi",
            "rndrng_prvdr_last_org_name",
            "rndrng_prvdr_first_name",
            "rndrng_prvdr_state_abrvtn",
            "rndrng_prvdr_type",
            "tot_benes",
            "tot_srvcs",
            "tot_sbmtd_chrg",
            "tot_mdcr_pymt_amt"
        ]
    ]
    .sort_values("tot_mdcr_pymt_amt", ascending=False)
)

top_payment_providers.head(25)
# Out:
#          rndrng_npi                         rndrng_prvdr_last_org_name  \
# 812603   1629407069                   Exact Sciences Laboratories, Llc
# 689528   1538144910         Laboratory Corporation Of America Holdings
# 234434   1184045619                              Guardant Health, Inc.
# 722501   1558672279                                       Natera, Inc.
# 82854    1063497451         Laboratory Corporation Of America Holdings
# 970217   1740733708                                    Tempus Ai, Inc.
# 840      1003053851                                               Jeng
# 888219   1689607384                                        Caredx Inc.
# 1207354  1932145778                     Quest Diagnostics Incorporated
# 1161896  1891731626        Quest Diagnostics Clinical Laboratories Inc
# 25188    1013973866                                    Caris Mpi, Inc.
# 923306   1710130539                         Irhythm Technologies, Inc.
# ...

# %%
os.makedirs("../data/processed/hive_outputs", exist_ok=True)

state_summary.to_csv("../data/processed/hive_outputs/state_summary.csv", index=False)
specialty_summary.to_csv("../data/processed/hive_outputs/specialty_summary.csv", index=False)
top_payment_providers.to_csv("../data/processed/hive_outputs/top_payment_providers.csv", index=False)

print("Hive-style analytics outputs saved successfully.")
# Out:
# Hive-style analytics outputs saved successfully.
