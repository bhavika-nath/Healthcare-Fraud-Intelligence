# %%
import os
print(os.getcwd())
# Out:
# /Users/bhavika2/Desktop/Healthcare-Fraud-Intelligence/Notebooks

# %%
import os
print(os.listdir(".."))
# Out:
# ['requirements.txt', 'Images', 'Models', 'README.md', 'logs', 'ai_assistant', '.gitignore', 'Dashboards', '.ipynb_checkpoints', 'data', 'Notebooks', 'Reports', 'Sql']

# %%
import os
print(os.listdir("../data"))
# Out:
# ['raws', '.ipynb_checkpoints', 'processed']

# %%
import os
print(os.listdir("../data/raws"))
# Out:
# []

# %%
import os

for root, dirs, files in os.walk("/Users/bhavika2/Dowmloads"):
    for file in files:
        if "MUP_PHY" in file:
            print(os.path.join(root, file))

# %%
import os

print(os.listdir("../data/raws"))
# Out:
# ['MUP_PHY_R26_P05_V10_D24_Prov.csv']

# %%
import pandas as pd

df = pd.read_csv("../data/raws/MUP_PHY_R26_P05_V10_D24_Prov.csv")

print(df.shape)
df.head()
# Out:
# /var/folders/xn/c_xvmpr50hjch8d1v89j72rr0000gq/T/ipykernel_53821/2283437631.py:3: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raws/MUP_PHY_R26_P05_V10_D24_Prov.csv")
# (1296739, 81)
#    Rndrng_NPI Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name  \
# 0  1003000126                  Enkeshafi                 Ardalan
# 1  1003000134                     Cibull                  Thomas
# 2  1003000142                     Khalil                  Rashid
# 3  1003000423                    Velotta                Jennifer
# 4  1003000480                  Rothchild                   Kevin
#
#   Rndrng_Prvdr_MI Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Ent_Cd  \
# 0             NaN                 M.D.                   I
# 1               L                 M.D.                   I
# 2             NaN                 M.D.                   I
# 3               A                 M.D.                   I
# ...

# %%
import shutil
import os

source = "/Users/bhavika2/Downloads/Medicare Physician & Other Practitioners - by Provider/2024/MUP_PHY_R26_P05_V10_D24_Prov.csv"
destination = "../data/raws/MUP_PHY_R26_P05_V10_D24_Prov.csv"

shutil.copy(source, destination)

print("Copied successfully!")
# Out:
# Copied successfully!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
print("="*50)
print("CMS Medicare Provider Dataset")
print("="*50)

print(f"Rows    : {df.shape[0]:,}")
print(f"Columns : {df.shape[1]}")
# Out:
# ...
# CMS Medicare Provider Dataset
# ...
# Rows    : 1,296,739
# Columns : 81

# %%
df.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Ent_Cd',
#        'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2', 'Rndrng_Prvdr_City',
#        'Rndrng_Prvdr_State_Abrvtn', 'Rndrng_Prvdr_State_FIPS',
#        'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA', 'Rndrng_Prvdr_RUCA_Desc',
#        'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'Tot_HCPCS_Cds', 'Tot_Benes',
#        'Tot_Srvcs', 'Tot_Sbmtd_Chrg', 'Tot_Mdcr_Alowd_Amt',
#        'Tot_Mdcr_Pymt_Amt', 'Tot_Mdcr_Stdzd_Amt', 'Drug_Sprsn_Ind',
#        'Drug_Tot_HCPCS_Cds', 'Drug_Tot_Benes', 'Drug_Tot_Srvcs',
#        'Drug_Sbmtd_Chrg', 'Drug_Mdcr_Alowd_Amt', 'Drug_Mdcr_Pymt_Amt',
#        'Drug_Mdcr_Stdzd_Amt', 'Med_Sprsn_Ind', 'Med_Tot_HCPCS_Cds',
#        'Med_Tot_Benes', 'Med_Tot_Srvcs', 'Med_Sbmtd_Chrg',
#        'Med_Mdcr_Alowd_Amt', 'Med_Mdcr_Pymt_Amt', 'Med_Mdcr_Stdzd_Amt',
# ...

# %%
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# 1. Rndrng_NPI
# 2. Rndrng_Prvdr_Last_Org_Name
# 3. Rndrng_Prvdr_First_Name
# 4. Rndrng_Prvdr_MI
# 5. Rndrng_Prvdr_Crdntls
# 6. Rndrng_Prvdr_Ent_Cd
# 7. Rndrng_Prvdr_St1
# 8. Rndrng_Prvdr_St2
# 9. Rndrng_Prvdr_City
# 10. Rndrng_Prvdr_State_Abrvtn
# 11. Rndrng_Prvdr_State_FIPS
# 12. Rndrng_Prvdr_Zip5
# 13. Rndrng_Prvdr_RUCA
# 14. Rndrng_Prvdr_RUCA_Desc
# 15. Rndrng_Prvdr_Cntry
# 16. Rndrng_Prvdr_Type
# 17. Rndrng_Prvdr_Mdcr_Prtcptg_Ind
# 18. Tot_HCPCS_Cds
# 19. Tot_Benes
# 20. Tot_Srvcs
# 21. Tot_Sbmtd_Chrg
# 22. Tot_Mdcr_Alowd_Amt
# 23. Tot_Mdcr_Pymt_Amt
# 24. Tot_Mdcr_Stdzd_Amt
# 25. Drug_Sprsn_Ind
# 26. Drug_Tot_HCPCS_Cds
# 27. Drug_Tot_Benes
# 28. Drug_Tot_Srvcs
# 29. Drug_Sbmtd_Chrg
# 30. Drug_Mdcr_Alowd_Amt
# 31. Drug_Mdcr_Pymt_Amt
# 32. Drug_Mdcr_Stdzd_Amt
# 33. Med_Sprsn_Ind
# 34. Med_Tot_HCPCS_Cds
# 35. Med_Tot_Benes
# 36. Med_Tot_Srvcs
# 37. Med_Sbmtd_Chrg
# 38. Med_Mdcr_Alowd_Amt
# 39. Med_Mdcr_Pymt_Amt
# 40. Med_Mdcr_Stdzd_Amt
# 41. Bene_Avg_Age
# 42. Bene_Age_LT_65_Cnt
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296739 entries, 0 to 1296738
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   Rndrng_NPI                        1296739 non-null  int64
#  1   Rndrng_Prvdr_Last_Org_Name        1296739 non-null  object
#  2   Rndrng_Prvdr_First_Name           1235756 non-null  object
#  3   Rndrng_Prvdr_MI                   810051 non-null   object
#  4   Rndrng_Prvdr_Crdntls              1123375 non-null  object
#  5   Rndrng_Prvdr_Ent_Cd               1296739 non-null  object
#  6   Rndrng_Prvdr_St1                  1296739 non-null  object
#  7   Rndrng_Prvdr_St2                  243316 non-null   object
#  8   Rndrng_Prvdr_City                 1296739 non-null  object
#  9   Rndrng_Prvdr_State_Abrvtn         1296739 non-null  object
#  10  Rndrng_Prvdr_State_FIPS           1296738 non-null  object
# ...

# %%
 df.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Ent_Cd',
#        'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2', 'Rndrng_Prvdr_City',
#        'Rndrng_Prvdr_State_Abrvtn', 'Rndrng_Prvdr_State_FIPS',
#        'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA', 'Rndrng_Prvdr_RUCA_Desc',
#        'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'Tot_HCPCS_Cds', 'Tot_Benes',
#        'Tot_Srvcs', 'Tot_Sbmtd_Chrg', 'Tot_Mdcr_Alowd_Amt',
#        'Tot_Mdcr_Pymt_Amt', 'Tot_Mdcr_Stdzd_Amt', 'Drug_Sprsn_Ind',
#        'Drug_Tot_HCPCS_Cds', 'Drug_Tot_Benes', 'Drug_Tot_Srvcs',
#        'Drug_Sbmtd_Chrg', 'Drug_Mdcr_Alowd_Amt', 'Drug_Mdcr_Pymt_Amt',
#        'Drug_Mdcr_Stdzd_Amt', 'Med_Sprsn_Ind', 'Med_Tot_HCPCS_Cds',
#        'Med_Tot_Benes', 'Med_Tot_Srvcs', 'Med_Sbmtd_Chrg',
#        'Med_Mdcr_Alowd_Amt', 'Med_Mdcr_Pymt_Amt', 'Med_Mdcr_Stdzd_Amt',
# ...

# %%
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# 1. Rndrng_NPI
# 2. Rndrng_Prvdr_Last_Org_Name
# 3. Rndrng_Prvdr_First_Name
# 4. Rndrng_Prvdr_MI
# 5. Rndrng_Prvdr_Crdntls
# 6. Rndrng_Prvdr_Ent_Cd
# 7. Rndrng_Prvdr_St1
# 8. Rndrng_Prvdr_St2
# 9. Rndrng_Prvdr_City
# 10. Rndrng_Prvdr_State_Abrvtn
# 11. Rndrng_Prvdr_State_FIPS
# 12. Rndrng_Prvdr_Zip5
# 13. Rndrng_Prvdr_RUCA
# 14. Rndrng_Prvdr_RUCA_Desc
# 15. Rndrng_Prvdr_Cntry
# 16. Rndrng_Prvdr_Type
# 17. Rndrng_Prvdr_Mdcr_Prtcptg_Ind
# 18. Tot_HCPCS_Cds
# 19. Tot_Benes
# 20. Tot_Srvcs
# 21. Tot_Sbmtd_Chrg
# 22. Tot_Mdcr_Alowd_Amt
# 23. Tot_Mdcr_Pymt_Amt
# 24. Tot_Mdcr_Stdzd_Amt
# 25. Drug_Sprsn_Ind
# 26. Drug_Tot_HCPCS_Cds
# 27. Drug_Tot_Benes
# 28. Drug_Tot_Srvcs
# 29. Drug_Sbmtd_Chrg
# 30. Drug_Mdcr_Alowd_Amt
# 31. Drug_Mdcr_Pymt_Amt
# 32. Drug_Mdcr_Stdzd_Amt
# 33. Med_Sprsn_Ind
# 34. Med_Tot_HCPCS_Cds
# 35. Med_Tot_Benes
# 36. Med_Tot_Srvcs
# 37. Med_Sbmtd_Chrg
# 38. Med_Mdcr_Alowd_Amt
# 39. Med_Mdcr_Pymt_Amt
# 40. Med_Mdcr_Stdzd_Amt
# 41. Bene_Avg_Age
# 42. Bene_Age_LT_65_Cnt
# ...

# %%
df.describe()
# Out:
#          Rndrng_NPI  Rndrng_Prvdr_RUCA  Tot_HCPCS_Cds     Tot_Benes  \
# count  1.296739e+06       1.295902e+06   1.296739e+06  1.296739e+06
# mean   1.499667e+09       1.595492e+00   2.559167e+01  2.814658e+02
# std    2.878453e+08       3.256244e+00   2.791739e+01  2.678782e+03
# min    1.003000e+09       1.000000e+00   1.000000e+00  1.100000e+01
# 25%    1.245955e+09       1.000000e+00   8.000000e+00  5.200000e+01
# 50%    1.497955e+09       1.000000e+00   1.600000e+01  1.300000e+02
# 75%    1.740940e+09       1.000000e+00   3.400000e+01  2.820000e+02
# max    1.993000e+09       9.900000e+01   8.330000e+02  1.560327e+06
#
#           Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Alowd_Amt  Tot_Mdcr_Pymt_Amt  \
# count  1.296739e+06    1.296739e+06        1.296739e+06       1.296739e+06
# mean   2.707430e+03    3.809556e+05        1.173363e+05       9.258447e+04
# std    4.563892e+04    3.336994e+06        8.490267e+05       7.698612e+05
# ...

# %%
df.describe(include="object")
# Out:
#        Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name Rndrng_Prvdr_MI  \
# count                     1296739                 1235756          810051
# unique                     304572                   89204              32
# top                   Walgreen Co                 Michael               M
# freq                         7136                   20679           99490
#
#        Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Ent_Cd Rndrng_Prvdr_St1  \
# count               1123375             1296739          1296739
# unique                19310                   2           443330
# top                      MD                   I    200 1st St Sw
# freq                 270854             1235757             4424
#
#        Rndrng_Prvdr_St2 Rndrng_Prvdr_City Rndrng_Prvdr_State_Abrvtn  \
# count            243316           1296739                   1296739
# unique            54730             12948                        62
# ...

# %%
missing = (
    df.isnull()
      .sum()
      .sort_values(ascending=False)
)

missing = missing[missing > 0]

missing
# Out:
# Med_Sprsn_Ind              1145043
# Drug_Sprsn_Ind             1145043
# Bene_Race_API_Cnt          1062540
# Rndrng_Prvdr_St2           1053423
# Bene_Race_Othr_Cnt         1052600
#                             ...
# Rndrng_Prvdr_First_Name      60983
# Rndrng_Prvdr_RUCA_Desc         837
# Rndrng_Prvdr_RUCA              837
# Rndrng_Prvdr_State_FIPS          1
# Rndrng_Prvdr_Zip5                1
# Length: 63, dtype: int64

# %%
missing_percent = (
    df.isnull().mean() * 100
).sort_values(ascending=False)

missing_percent = missing_percent[missing_percent > 0]

missing_percent
# Out:
# Med_Sprsn_Ind              88.301732
# Drug_Sprsn_Ind             88.301732
# Bene_Race_API_Cnt          81.939388
# Rndrng_Prvdr_St2           81.236317
# Bene_Race_Othr_Cnt         81.172850
#                              ...
# Rndrng_Prvdr_First_Name     4.702797
# Rndrng_Prvdr_RUCA_Desc      0.064547
# Rndrng_Prvdr_RUCA           0.064547
# Rndrng_Prvdr_State_FIPS     0.000077
# Rndrng_Prvdr_Zip5           0.000077
# Length: 63, dtype: float64

# %%
duplicates = df.duplicated(subset="Rndrng_NPI").sum()

print("Duplicate NPIs:", duplicates)
# Out:
# Duplicate NPIs: 0

# %%
df["Rndrng_Prvdr_State_Abrvtn"].value_counts().head(20)
# Out:
# Rndrng_Prvdr_State_Abrvtn
# CA    105363
# NY     88642
# TX     86803
# FL     85872
# PA     63361
# OH     52310
# IL     51368
# NC     44655
# MI     43221
# NJ     39694
# MA     38948
# GA     37050
# VA     32889
# TN     30048
# MN     29299
# WA     29103
# WI     26902
# AZ     26694
# MD     26679
# IN     26454
# Name: count, dtype: int64

# %%
df["Rndrng_Prvdr_Type"].value_counts().head(20)
# Out:
# Rndrng_Prvdr_Type
# Nurse Practitioner                               203212
# Physician Assistant                              112514
# Internal Medicine                                 93627
# Family Practice                                   83639
# Physical Therapist in Private Practice            77901
# Certified Registered Nurse Anesthetist (CRNA)     53495
# Emergency Medicine                                50101
# Anesthesiology                                    41082
# Diagnostic Radiology                              32843
# Chiropractic                                      32394
# Optometry                                         31979
# Mass Immunizer Roster Biller                      26738
# Obstetrics & Gynecology                           22815
# Orthopedic Surgery                                21674
# General Surgery                                   21065
# Hospitalist                                       20529
# ...

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

len(numeric_cols)
# Out:
# 64

# %%
numeric_cols
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_RUCA', 'Tot_HCPCS_Cds', 'Tot_Benes',
#        'Tot_Srvcs', 'Tot_Sbmtd_Chrg', 'Tot_Mdcr_Alowd_Amt',
#        'Tot_Mdcr_Pymt_Amt', 'Tot_Mdcr_Stdzd_Amt', 'Drug_Tot_HCPCS_Cds',
#        'Drug_Tot_Benes', 'Drug_Tot_Srvcs', 'Drug_Sbmtd_Chrg',
#        'Drug_Mdcr_Alowd_Amt', 'Drug_Mdcr_Pymt_Amt', 'Drug_Mdcr_Stdzd_Amt',
#        'Med_Tot_HCPCS_Cds', 'Med_Tot_Benes', 'Med_Tot_Srvcs', 'Med_Sbmtd_Chrg',
#        'Med_Mdcr_Alowd_Amt', 'Med_Mdcr_Pymt_Amt', 'Med_Mdcr_Stdzd_Amt',
#        'Bene_Avg_Age', 'Bene_Age_LT_65_Cnt', 'Bene_Age_65_74_Cnt',
#        'Bene_Age_75_84_Cnt', 'Bene_Age_GT_84_Cnt', 'Bene_Feml_Cnt',
#        'Bene_Male_Cnt', 'Bene_Race_Wht_Cnt', 'Bene_Race_Black_Cnt',
#        'Bene_Race_API_Cnt', 'Bene_Race_Hspnc_Cnt', 'Bene_Race_NatInd_Cnt',
#        'Bene_Race_Othr_Cnt', 'Bene_Dual_Cnt', 'Bene_Ndual_Cnt',
#        'Bene_CC_BH_ADHD_OthCD_V1_Pct', 'Bene_CC_BH_Alcohol_Drug_V1_Pct',
# ...

# %%
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# np.float64(1775.758689880371)

# %%
df_original = df.copy()
